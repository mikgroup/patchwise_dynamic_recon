# %%
# %matplotlib notebook
import numpy as np
import sigpy.plot as pl
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
converg = np.load("converge1.npy")
M = np.load("M11.npy")

# %%
pl.LinePlot(converg)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
converg[-1]
# Out:
# array(nan)

# %%
pl.ImagePlot(M)
# Out:
# <img src="data:image/png;base64,..." width="640">
